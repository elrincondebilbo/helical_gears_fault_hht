# %% [markdown]
# # Hilbert-Huang Transform Testing
#
# * *Author:* Mario Paul Tafur Díaz
# * *Contact:* mariop.tafur@gmail.com / 71491743@usat.pe
#
# This `Python` notebook will be the base to set how the `emd` package  will perform.
# The preliminary data was provided by my advisor.

# %% [markdown]
# ## Data visualization
# Plotting the data for a better understanding. It is clear that it has no stationary nor linear behavior.

# %%
import pandas as pd
import matplotlib.pyplot as plt

excel_file_path = 'Test_data.xlsx'
var = pd.read_excel(excel_file_path)

x = list(var['X-Axis'])
y = list(var['Ch1 Y-Axis'])

plt.figure(figsize=(10,10))
plt.style.use('seaborn')
plt.plot(x,y)
plt.title("Test data")
plt.xlabel('Tiempo [s]')
plt.ylabel('Vibración')
plt.show()
# Out:
# C:\Users\Mario\AppData\Local\Temp\ipykernel_2988\1328637905.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## EMD
#
# Trying to implement the EMD to the test data.
